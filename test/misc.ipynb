# %%
import numpy as np
import matplotlib.pyplot as plt
import os, sys
sys.path.insert(1, os.getcwd()) 
sys.path.append("..")

# %%
from uilc.utils.misc import extend_signal, half_ceil

# %%
time = np.linspace(-np.pi, np.pi, 50, endpoint=True)
sig = np.sin(time)
sig_poly = time**4+2*time**2

# %%
fig = plt.figure()
ax =fig.add_subplot()
ax.plot(time, sig)
ax.plot(time, sig_poly)
plt.show()

# %%
period = 1.5*np.pi

# %%
sig_poly_ext, time_ext = extend_signal(
    sig_poly, time, 4, 
    central=False,
    edge_matching=False)

# %%
sig_ext.shape
# Out:
# (200,)

# %%
time_ext.shape
# Out:
# (200,)

# %%
fig = plt.figure()
ax = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2,1, 2)
ax.stem(time, sig_poly)
ax.set_xlim([-0.2*np.pi, 0.2*np.pi])
ax2.stem(time_ext, sig_poly_ext)
ax2.set_xlim([-0.2*np.pi, 0.2*np.pi])
plt.show()
